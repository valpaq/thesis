# %%
p=57896044618658097711785492504343953926634992332820282019728792003956565153471
K = GF(p)
q=14474011154664524427946373126085988481777980136002577561989638920376330856411
aWeier = K(14474011154664524427946373126085988481658748083205070504932198000989141288364)
bWeier = K(14474011154664524427946373126085988481658748083205070504932198000989141288365)
xWeier = K(1)
yWeier = K(1370184815209153778412612456839413869416711536549829925085495630500881379458)
zWeier = K(1)
alpha = K(-3).sqrt()
gamma = K(2)

# %%
additions = 0
multiplications=0

# %%
def add(a, b):
    global additions
    additions += 1
    return a+b
def mul(a, b):
    global multiplications
    multiplications += 1
    return a*b

# %%
def addTwoPointsWeierstrass(x1, y1, z1, x2, y2, z2, a, b, ):
    if(x1==x2 and y1==y2):
        w=add(mul(a,mul(z1,z1)),mul(3, mul(x1,x1)))
        s=mul(y1,z1)
        ss=mul(s, s)
        sss = mul(s, ss)
        r=mul(y1, s)
        b=mul(x1, r)
        b4=mul(4, b)
        h=add(mul(w, w), -add(b4, b4))
        x3=mul(h, s)
        x3=add(x3,x3)
        y3=add(mul(w, add(b4, -h)),-mul(8, mul(r,r)))
        z3=mul(8, sss)
    else:
        y1z2=mul(y1,z2)
        x1z2=mul(x1,z2)
        z1z2=mul(z1,z2)
        u=add(mul(y2,z1),-y1z2)
        uu=mul(u,u)
        v=add(mul(x2,z1),-x1z2)
        vv=mul(v,v)
        vvv=mul(v, vv)
        R=mul(vv, x1z2)
        A=add(mul(uu, z1z2),-add(vvv, add(R, R)))
        x3=mul(v, A)
        y3=add(mul(u, add(R, -A)), -mul(vvv, y1z2))
        z3=mul(vvv, z1z2)
    return x3, y3, z3

# %%
addTwoPointsWeierstrass(aWeier, bWeier, xWeier, yWeier, zWeier, xWeier, yWeier, zWeier)
# Out:
# (20603904670834645468580229852244388859270111775432385519915925046572775578253,
#  8777153777661139624351339573670995835579111346988115026467202711985232462330,
#  5941996246825723184926951811657656609145688492356356955219264565971840413230)

# %%
multiplications
# Out:
# 14

# %%
def convertWeierStrassToMontgomeryCoeffs(a, b):
    R.<x> = PolynomialRing(K, 'x')
    equation = x^3 + a*x + b
    roots = equation.roots(multiplicities=False)
    theta = roots[0]
    gamma = sqrt(3*theta^2+a)
    mu=3*theta/gamma
    return gamma, mu
def convertWeierStrassToMontgomeryPoints(a, b, x, y):
    R.<x> = PolynomialRing(K, 'x')
    equation = x^3 + a*x + b
    roots = equation.roots(multiplicities=False)
    theta = roots[0]
    gamma = sqrt(3*theta^2+a)
    xMont = (xWeier-theta)/gamma
    yMont = yWeier / gamma^2
    return xMont, yMont
def convertMontgomeryToWeierstrassCoeffs(gamma, mu):
    theta = gamma * mu / 3
    a = gamma^2 - 3*theta^2
    b = -(theta^3 + a*theta)
    return a, b

def convertMontgomeryToWeierstrassPoints(gamma, mu, x, y):
    theta = gamma * mu / 3
    xWeier = gamma * x + theta
    yWeier = gamma^2 * y
    return xWeier, yWeier

# %%
gammaMont, muMont = convertWeierStrassToMontgomeryCoeffs(aWeier, bWeier)
xMont, yMont = convertWeierStrassToMontgomeryPoints(aWeier, bWeier, xWeier, yWeier)
zMont = K(1)

# %%
xWeier, yWeier, convertMontgomeryToWeierstrassPoints(gammaMont, muMont, xMont, yMont)
# Out:
# (1,
#  1370184815209153778412612456839413869416711536549829925085495630500881379458,
#  (1,
#   1370184815209153778412612456839413869416711536549829925085495630500881379458))

# %%
def convertMontgomeryToEdwardsCoeffs(gamma, mu):
    e = (mu + 2)/gamma
    d = (mu - 2)/gamma
    return e, d

def convertMontgomeryToEdwardsPoints(gamma, mu, x, y):
    xEdwards = x/y
    yEdwards = (x-1)/(x+1)
    return xEdwards, yEdwards

def convertEdwardsToMontgomeryCoeffs(e, d):
    mu = 2 * (e + d) / (e - d)
    gamma = 4 / (e - d)
    return gamma, mu

def convertEdwardsToMontgomeryPoints(e, d, x, y):
    xMont = (1 + y) / (1 - y)
    yMont = xMont/x
    return xMont, yMont

# %%
eEdwards, dEdwards = convertMontgomeryToEdwardsCoeffs(gammaMont, muMont)
xEdwards, yEdwards = convertMontgomeryToEdwardsPoints(gammaMont, muMont, xMont, yMont)
zEdwards = K(1)

# %%
def convertWeierstrassToHadanoCoeffs(a, b, gamma):
    R.<x> = PolynomialRing(K, 'x')
    equation = x^3 + a*x + b
    roots = equation.roots(multiplicities=False)
    theta = roots[0]
    newA = 3*theta*gamma
    newB = (3*theta^2 + a) * gamma^2
    return newA, newB

def convertWeierstrassToHadanoPoints(a, b, gamma, xWeier, yWeier):
    R.<x> = PolynomialRing(K, 'x')
    equation = x^3 + a*x + b
    roots = equation.roots(multiplicities=False)
    theta = roots[0]
    xHadano = gamma * (xWeier-theta)
    yHadano = (gamma.sqrt() ** 3) * yWeier
    return xHadano, yHadano

# def convertHadanoToWeierstrassCoeffs(a, b, gamma):
    
#     return 

# def convertEdwardsToMontgomeryPoints(e, d, x, y):
#     xMont = (1 + y) / (1 - y)
#     yMont = xMont/x
#     return xMont, yMont

# %%
xHadano, yHadano = convertWeierstrassToHadanoPoints(aWeier, bWeier, gamma, xWeier, yWeier)
aHadano, bHadano = convertWeierstrassToHadanoCoeffs(aWeier, bWeier, gamma)

# %%
zHadano = K(1)

# %%
def addTwoPointsEdwards(x1, y1, z1, x2, y2, z2, e, d):
    if(x1==x2 and y1==y2 and z1 == z2):
        B = add(x1,y1)
        B = mul(B, B)
        C = mul(x1, x1)
        D = mul(y1, y1)
        E = mul(e, C)
        F = add(E, D)
        H = mul(z1, z1)
        J = add(F, -add(H, H))
        x3 = mul(add(B, -add(C, D)), J)
        y3 = mul(F, add(E, -D))
        z3 = mul(F, J)
    else:
        A = mul(z1, z2)
        B = mul(A, A)
        C = mul(x1, x2)
        D = mul(y1, y2)
        E = mul(d, mul(C, D))
        F = add(B, -E)
        G = add(B, E)
        x3 = mul(mul(A, F), add(mul(add(x1, y1), add(x2, y2)), -add(C, D)))
        y3 = mul(mul(A, G), add(D, -mul(e, C)))
        z3 = mul(F, G)
    return x3, y3, z3

# %%
def addTwoPointsHadano(x1, y1, z1, x2, y2, z2, a, b):
    if(x1==x2 and y1==y2 and z1 == z2):
        y1z1 = mul(y1, z1)
        y12z1 = mul(y1z1, y1)
        az1 = mul(a, z1)
        x12 = add(x1, x1)
        ax12z1 = mul(az1, x12)
        z12 = mul(z1, z1)
        bz12 = mul(b, z12)
        delta = add(add(mul(3, mul(x1, x1)), ax12z1), bz12)
        delta2 = mul(delta, delta)
        y12z14 = mul(4, y12z1)
        y13z12 = mul(y12z14, y1z1)
        az1p2x = add(az1, x12)
        z3 = mul(y13z12, add(z1, z1))
        x3 = add(-mul(y12z14, az1p2x), delta2)
        y3 = add(mul(y12z14, add(-add(y12z1, y12z1),
                                 mul(x1, delta))), -mul(x3, delta))
        x3 = mul(x3, add(y1z1,y1z1)) 
    else:
        z1z2 = mul(z1, z2)
        y2z1 = mul(y2, z1)
        y1z2 = mul(y1, z2)
        x2z1 = mul(x2, z1)
        x1z2 = mul(x1, z2)
        llambda = add(y2z1, -y1z2)
        delta = add(x2z1, -x1z2)
        llambda2 = mul(llambda, llambda)
        delta2 = mul(delta, delta)
        deltap = add(x2z1, x1z2)
        adelta2 = mul(a, delta2)
        x3 = add(mul(z1z2, add(llambda2, -adelta2)), -mul(delta2, deltap))
        z3 = mul(mul(z1z2, delta2), delta)
        y3 = add(mul(mul(z2, delta2), add(-mul(y1, delta), 
                            mul(llambda, x1))), -mul(llambda, x3))
        x3 = mul(x3, delta)        
    return x3, y3, z3

# %%
def endomorphismHadano(x, y, z, alpha):
    xx1 = add(x, K(1))
    xx1xx1 = mul(xx1, xx1)
    z13 = mul(K(3), z)
    xx3 = add(x, -z13)
    delta = mul(alpha, xx1)
    znew = mul(mul(z13,delta), xx1xx1)
    xnew = -mul(mul(delta, x), mul(xx3, xx3))
    x1z13 = mul(x, z13)
    ynew = mul(mul(xx3, add(add(mul(x, x), 
                                add(x1z13, x1z13)), mul(z13, z))), y)
    return xnew, ynew, znew

# %%
additions = 0
multiplications=0
tmpxHadano, tmpyHadano, tmpzHadano = addTwoPointsHadano(xHadano, yHadano, zHadano, xHadano, yHadano, zHadano, aHadano, bHadano)
additions, multiplications
# Out:
# (10, 17)

# %%
additions = 0
multiplications=0
tmpxWeier, tmpyWeier, tmpzWeier = addTwoPointsWeierstrass(xWeier, yWeier, zWeier, xWeier, yWeier, zWeier, aWeier, bWeier)
additions, multiplications
# Out:
# (6, 16)

# %%
additions = 0
multiplications=0
tmpxWeier, tmpyWeier, tmpzWeier = addTwoPointsWeierstrass(xWeier, yWeier, zWeier, tmpxWeier, tmpyWeier, tmpzWeier, aWeier, bWeier)
additions, multiplications
# Out:
# (7, 14)

# %%
additions = 0
multiplications=0
tmpxHadano, tmpyHadano, tmpzHadano = addTwoPointsHadano(xHadano, yHadano, zHadano, tmpxHadano, tmpyHadano, tmpzHadano, aHadano, bHadano)
additions, multiplications
# Out:
# (7, 18)

# %%
from timeit import default_timer as timer
def multiplyPointStandardVersion(Px, Py, Pz, k, a, b, func):
    binary = Integer(k).digits(base=2)[::-1]
    resx, resy, resz = 0, 1, 0
    px, py, pz = Px, Py, Pz

    for digit in binary:
        if digit == 1:
            resx, resy, resz = func(resx, resy, resz, px, py, pz, a, b)
        px, py, pz = func(px, py, pz, px, py, pz, a, b)

    return resx, resy, resz


def multiplyPointEndoVersion(Px, Py, Pz, k, a, b, func1, func2, AComplex, p):
    binary = calculateW(AComplex, k)
    resx, resy, resz = 0, 1, 0
    px, py, pz = Px, Py, Pz
    before = timer()

    for digit in binary:
        if digit == 1:
            resx, resy, resz = func1(resx, resy, resz, px, py, pz, a, b)
        if digit == -1:
            tmpy = add(p, -py)
            resx, resy, resz = func1(resx, resy, resz, px, tmpy, pz, a, b)
        px, py, pz = func2(px, py, pz, alpha)
        
    after = timer()
    return resx, resy, resz, after - before
def tr(a):
    return (a + conjugate(a)).real().n(digits=2048)

def nA(a):
    return (conjugate(a) * a).real().n(digits=2048)

def calculateW(a, k):
    na = nA(a)
    trA = tr(a)
    sigmaA = round(na) % 2
    nAa = (na - sigmaA) / 2
    s0 = k
    s1 = 0
    wArray = [0] * (round(2 * log(k) / log(na)) + 5)
    w = 0
    while True:
        q = quotient(s0, na)
        xW = s0 % na
        if xW > nAa:
            xW = xW - na
            q += 1
        wArray[w] = round(xW.real())
        s0 = round((q * trA + s1).real())
        s1 = -q
        w += 1
        if abs(s0) < nAa and s1 == 0:
            break

    return wArray

# %%
calculateW(sqrt(-7), 9)
# Out:
# [2, 0, 0, 0, 0, 0, 0]

# %%
calculateW(sqrt(-3), 9)
# Out:
# [0, 0, 0, 0, 1, 0, 0, 0, 0]

# %%
def montgomeryAddPoints(x1, z1, x2, z2, mx1, mz1):
    a = add(x1,-z1); 
    b = add(x1, z1); 
    c = add(x2,-z2); 
    d = add(x2, z2)
    e = mul(a,d); 
    f = mul(b, c);
    epf = add(e, f)
    emf = add(e, -f)
    x3 = mul(mz1, mul(epf, epf))
    z3 = mul(mx1, mul(emf, emf))
    return [x3, z3]

def montgomeryDoublePoint(x, z, C):
    a=add(x, z);
    b=add(x, -z);
    c=mul(a, a); 
    d=mul(b, b); 
    e=add(c, -d)
    x3 = mul(c, d)
    z3 = mul(e, add(d, mul(C, e)))
    return [x3, z3]
    
def montgomeryLadder(x, z, n, mu):
    C = (mu + 2) / 4
    Q = [[x, z], montgomeryDoublePoint(x, z, C)]
    b = Integer(n).digits(base=2)
    for i in range(len(b)-2,-1,-1):
        Q[Integer(1)-b[i]] = montgomeryAddPoints(Q[1][0], Q[1][1], Q[0][0], Q[0][1], x, z)
        Q[b[i]] = montgomeryDoublePoint(Q[b[i]][0], Q[b[i]][1],C)
    return Q[0][0], Q[0][1]

# %%
floor(log(q,10))
# Out:
# 76

# %%
import random
from timeit import default_timer as timer
results = []  # Список для хранения результатов

for i in range(2, 75):
    j = round(log(10**i, 2)*2)  # Вычисляем j
    numbers = [random.randint(10**i, 10**(i+1) - 1) for _ in range(j)]  # Генерируем j случайных чисел
    for number in numbers:
        additions = 0  # Счетчик сложений
        multiplications = 0  # Счетчик умножений


        start = timer()
        multiplyPointStandardVersion(xWeier, yWeier, zWeier, number, aWeier, bWeier, addTwoPointsWeierstrass)
        end = timer()
        weierTime = end - start
        
        weierAdditions = additions
        weierMultiplications = multiplications
        
        additions = 0
        multiplications = 0

        start = timer()
        montgomeryLadder(xMont, zMont, number, muMont) 
        end = timer()
        montTime = end - start
        
        
        montAdditions = additions
        montMultiplications = multiplications
        
        additions = 0
        multiplications = 0

        start = timer()
        multiplyPointStandardVersion(xHadano, yHadano, zHadano, number, aHadano, bHadano, addTwoPointsHadano)
        end = timer()
        hadanoTime = end - start
        
        hadanoAdditions = additions
        hadanoMultiplications = multiplications
        
                
        additions = 0
        multiplications = 0

        start = timer()
        multiplyPointStandardVersion(xEdwards, yEdwards, zEdwards, number, eEdwards, dEdwards, addTwoPointsEdwards)
        end = timer()
        edwardsTime = end - start
        
        edwardsAdditions = additions
        edwardsMultiplications = multiplications
        
                
        additions = 0
        multiplications = 0

        _, _, _, endoTime = multiplyPointEndoVersion(xHadano, yHadano, zHadano, number, aHadano, bHadano, addTwoPointsHadano, endomorphismHadano, sqrt(-3), p)
        
        endoAddition = additions
        endoMultiplications = multiplications

        results.append({'number': str(number), "endoMultiplications": str(endoMultiplications), "endoAdditions": str(endoAddition),
                       "weierAdditions": str(weierAdditions), "weierMultiplications": str(weierMultiplications), 
                       "montAdditions": str(montAdditions), "montMultiplications": str(montMultiplications),
                       "hadanoAdditions": str(hadanoAdditions), "hadanoMultiplications": str(hadanoMultiplications),
                       "edwardsAdditions": str(edwardsAdditions), "edwardsMultiplications": str(edwardsMultiplications),
                       "weierTime": weierTime, "endoTime": endoTime, "edwardsTime": edwardsTime, "montTime": montTime, "hadanoTime": hadanoTime})

# %%
len(results)
# Out:
# 18430

# %%
import json
with open('resultsWithEndo.json', 'w') as f:
    json.dump(results, f)

# %%
results
# Out:
# [{'number': 959,
#   'endoMultiplications': 311,
#   'endoAddition': 123,
#   'weierAdditions': 123,
#   'weierMultiplications': 286,
#   'montAdditions': 94,
#   'montMultiplications': 104,
#   'hadanoAdditions': 163,
#   'hadanoMultiplications': 332,
#   'edwardsAdditions': 133},
#  {'number': 936,
#   'endoMultiplications': 293,
#   'endoAddition': 115,
#   'weierAdditions': 95,
#   'weierMultiplications': 230,
#   'montAdditions': 94,
#   'montMultiplications': 104,
#   'hadanoAdditions': 135,
#   'hadanoMultiplications': 260,
#   'edwardsAdditions': 105},
#  {'number': 831,
#   'endoMultiplications': 311,
#   'endoAddition': 123,
#   'weierAdditions': 116,
#   'weierMultiplications': 272,
#   'montAdditions': 94,
#   'montMultiplications': 104,
#   'hadanoAdditions': 156,
#   'hadanoMultiplications': 314,
#   'edwardsAdditions': 126},
#  {'number': 828,
#   'endoMultiplications': 293,
#   'endoAddition': 115,
#   'weierAdditions': 102,
#   'weierMultiplications': 244,
#   'montAdditions': 94,
#   'montMultiplications': 104,
#   'hadanoAdditions': 142,
#   'hadanoMultiplications': 278,
#   'edwardsAdditions': 112},
#  {'number': 569,
#   'endoMultiplications': 311,
#   'endoAddition': 122,
#   'weierAdditions': 95,
#   'weierMultiplications': 230,
#   'montAdditions': 94,
#   'montMultiplications': 104,
#   'hadanoAdditions': 135,
#   'hadanoMultiplications': 260,
#   'edwardsAdditions': 105},
#  {'number': 796,
#   'endoMultiplications': 329,
#   'endoAddition': 128,
#   'weierAdditions': 95,
#   'weierMultiplications': 230,
#   'montAdditions': 94,
#   'montMultiplications': 104,
#   'hadanoAdditions': 135,
#   'hadanoMultiplications': 260,
#   'edwardsAdditions': 105},
#  {'number': 466,
#   'endoMultiplications': 316,
#   'endoAddition': 122,
#   'weierAdditions': 89,
#   'weierMultiplications': 214,
#   'montAdditions': 84,
#   'montMultiplications': 93,
#   'hadanoAdditions': 125,
#   'hadanoMultiplications': 243,
#   'edwardsAdditions': 98},
#  {'number': 8571,
#   'endoMultiplications': 399,
#   'endoAddition': 156,
#   'weierAdditions': 140,
#   'weierMultiplications': 336,
#   'montAdditions': 134,
#   'montMultiplications': 148,
#   'hadanoAdditions': 196,
#   'hadanoMultiplications': 382,
#   'edwardsAdditions': 154},
#  {'number': 5994,
#   'endoMultiplications': 345,
#   'endoAddition': 136,
#   'weierAdditions': 134,
#   'weierMultiplications': 320,
#   'montAdditions': 124,
#   'montMultiplications': 137,
#   'hadanoAdditions': 186,
#   'hadanoMultiplications': 365,
#   'edwardsAdditions': 147},
#  {'number': 5081,
#   'endoMultiplications': 399,
#   'endoAddition': 155,
#   'weierAdditions': 134,
#   'weierMultiplications': 320,
#   'montAdditions': 124,
#   'montMultiplications': 137,
#   'hadanoAdditions': 186,
#   'hadanoMultiplications': 365,
#   'edwardsAdditions': 147},
#  {'number': 8968,
#   'endoMultiplications': 394,
#   'endoAddition': 155,
#   'weierAdditions': 112,
#   'weierMultiplications': 280,
#   'montAdditions': 134,
#   'montMultiplications': 148,
#   'hadanoAdditions': 168,
#   'hadanoMultiplications': 310,
#   'edwardsAdditions': 126},
#  {'number': 2832,
#   'endoMultiplications': 319,
#   'endoAddition': 125,
#   'weierAdditions': 100,
#   'weierMultiplications': 248,
#   'montAdditions': 114,
#   'montMultiplications': 126,
#   'hadanoAdditions': 148,
#   'hadanoMultiplications': 276,
#   'edwardsAdditions': 112},
#  {'number': 7963,
#   'endoMultiplications': 399,
#   'endoAddition': 158,
#   'weierAdditions': 141,
#   'weierMultiplications': 334,
#   'montAdditions': 124,
#   'montMultiplications': 137,
#   'hadanoAdditions': 193,
#   'hadanoMultiplications': 383,
#   'edwardsAdditions': 154},
#  {'number': 1866,
#   'endoMultiplications': 319,
#   'endoAddition': 126,
#   'weierAdditions': 108,
#   'weierMultiplications': 260,
#   'montAdditions': 104,
#   'montMultiplications': 115,
#   'hadanoAdditions': 152,
#   'hadanoMultiplications': 295,
#   'edwardsAdditions': 119},
#  {'number': 5469,
#   'endoMultiplications': 399,
#   'endoAddition': 157,
#   'weierAdditions': 134,
#   'weierMultiplications': 320,
#   'montAdditions': 124,
#   'montMultiplications': 137,
#   'hadanoAdditions': 186,
#   'hadanoMultiplications': 365,
#   'edwardsAdditions': 147},
#  {'number': 2809,
#   'endoMultiplications': 337,
#   'endoAddition': 132,
#   'weierAdditions': 128,
#   'weierMultiplications': 304,
#   'montAdditions': 114,
#   'montMultiplications': 126,
#   'hadanoAdditions': 176,
#   'hadanoMultiplications': 348,
#   'edwardsAdditions': 140},
#  {'number': 9878,
#   'endoMultiplications': 430,
#   'endoAddition': 171,
#   'weierAdditions': 133,
#   'weierMultiplications': 322,
#   'montAdditions': 134,
#   'montMultiplications': 148,
#   'hadanoAdditions': 189,
#   'hadanoMultiplications': 364,
#   'edwardsAdditions': 147},
#  {'number': 64739,
#   'endoMultiplications': 487,
#   'endoAddition': 193,
#   'weierAdditions': 173,
#   'weierMultiplications': 410,
#   'montAdditions': 154,
#   'montMultiplications': 170,
#   'hadanoAdditions': 237,
#   'hadanoMultiplications': 470,
#   'edwardsAdditions': 189},
#  {'number': 47226,
#   'endoMultiplications': 469,
#   'endoAddition': 184,
#   'weierAdditions': 159,
#   'weierMultiplications': 382,
#   'montAdditions': 154,
#   'montMultiplications': 170,
#   'hadanoAdditions': 223,
#   'hadanoMultiplications': 434,
#   'edwardsAdditions': 175},
#  {'number': 44542,
#   'endoMultiplications': 456,
#   'endoAddition': 177,
#   'weierAdditions': 180,
#   'weierMultiplications': 424,
#   'montAdditions': 154,
#   'montMultiplications': 170,
#   'hadanoAdditions': 244,
#   'hadanoMultiplications': 488,
#   'edwardsAdditions': 196},
#  {'number': 52508,
#   'endoMultiplications': 433,
#   'endoAddition': 172,
#   'weierAdditions': 152,
#   'weierMultiplications': 368,
#   'montAdditions': 154,
#   'montMultiplications': 170,
#   'hadanoAdditions': 216,
#   'hadanoMultiplications': 416,
#   'edwardsAdditions': 168},
#  {'number': 41250,
#   'endoMultiplications': 456,
#   'endoAddition': 181,
#   'weierAdditions': 131,
#   'weierMultiplications': 326,
#   'montAdditions': 154,
#   'montMultiplications': 170,
#   'hadanoAdditions': 195,
#   'hadanoMultiplications': 362,
#   'edwardsAdditions': 147},
#  {'number': 57648,
#   'endoMultiplications': 433,
#   'endoAddition': 168,
#   'weierAdditions': 138,
#   'weierMultiplications': 340,
#   'montAdditions': 154,
#   'montMultiplications': 170,
#   'hadanoAdditions': 202,
#   'hadanoMultiplications': 380,
#   'edwardsAdditions': 154},
#  {'number': 19650,
#   'endoMultiplications': 371,
#   'endoAddition': 146,
#   'weierAdditions': 132,
#   'weierMultiplications': 324,
#   'montAdditions': 144,
#   'montMultiplications': 159,
#   'hadanoAdditions': 192,
#   'hadanoMultiplications': 363,
#   'edwardsAdditions': 147},
#  {'number': 39339,
#   'endoMultiplications': 366,
#   'endoAddition': 141,
#   'weierAdditions': 159,
#   'weierMultiplications': 382,
#   'montAdditions': 154,
#   'montMultiplications': 170,
#   'hadanoAdditions': 223,
#   'hadanoMultiplications': 434,
#   'edwardsAdditions': 175},
#  {'number': 57809,
#   'endoMultiplications': 451,
#   'endoAddition': 177,
#   'weierAdditions': 152,
#   'weierMultiplications': 368,
#   'montAdditions': 154,
#   'montMultiplications': 170,
#   'hadanoAdditions': 216,
#   'hadanoMultiplications': 416,
#   'edwardsAdditions': 168},
#  {'number': 73121,
#   'endoMultiplications': 487,
#   'endoAddition': 192,
#   'weierAdditions': 158,
#   'weierMultiplications': 384,
#   'montAdditions': 164,
#   'montMultiplications': 181,
#   'hadanoAdditions': 226,
#   'hadanoMultiplications': 433,
#   'edwardsAdditions': 175},
#  {'number': 23845,
#   'endoMultiplications': 425,
#   'endoAddition': 167,
#   'weierAdditions': 146,
#   'weierMultiplications': 352,
#   'montAdditions': 144,
#   'montMultiplications': 159,
#   'hadanoAdditions': 206,
#   'hadanoMultiplications': 399,
#   'edwardsAdditions': 161},
#  {'number': 80508,
#   'endoMultiplications': 482,
#   'endoAddition': 192,
#   'weierAdditions': 172,
#   'weierMultiplications': 412,
#   'montAdditions': 164,
#   'montMultiplications': 181,
#   'hadanoAdditions': 240,
#   'hadanoMultiplications': 469,
#   'edwardsAdditions': 189},
#  {'number': 61160,
#   'endoMultiplications': 433,
#   'endoAddition': 170,
#   'weierAdditions': 166,
#   'weierMultiplications': 396,
#   'montAdditions': 154,
#   'montMultiplications': 170,
#   'hadanoAdditions': 230,
#   'hadanoMultiplications': 452,
#   'edwardsAdditions': 182},
#  {'number': 563652,
#   'endoMultiplications': 521,
#   'endoAddition': 205,
#   'weierAdditions': 176,
#   'weierMultiplications': 432,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 256,
#   'hadanoMultiplications': 484,
#   'edwardsAdditions': 196},
#  {'number': 853344,
#   'endoMultiplications': 570,
#   'endoAddition': 225,
#   'weierAdditions': 169,
#   'weierMultiplications': 418,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 249,
#   'hadanoMultiplications': 466,
#   'edwardsAdditions': 189},
#  {'number': 850887,
#   'endoMultiplications': 588,
#   'endoAddition': 233,
#   'weierAdditions': 218,
#   'weierMultiplications': 516,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 298,
#   'hadanoMultiplications': 592,
#   'edwardsAdditions': 238},
#  {'number': 537775,
#   'endoMultiplications': 503,
#   'endoAddition': 196,
#   'weierAdditions': 190,
#   'weierMultiplications': 460,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 270,
#   'hadanoMultiplications': 520,
#   'edwardsAdditions': 210},
#  {'number': 687427,
#   'endoMultiplications': 539,
#   'endoAddition': 209,
#   'weierAdditions': 197,
#   'weierMultiplications': 474,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 277,
#   'hadanoMultiplications': 538,
#   'edwardsAdditions': 217},
#  {'number': 984035,
#   'endoMultiplications': 552,
#   'endoAddition': 220,
#   'weierAdditions': 197,
#   'weierMultiplications': 474,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 277,
#   'hadanoMultiplications': 538,
#   'edwardsAdditions': 217},
#  {'number': 681776,
#   'endoMultiplications': 521,
#   'endoAddition': 207,
#   'weierAdditions': 183,
#   'weierMultiplications': 446,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 263,
#   'hadanoMultiplications': 502,
#   'edwardsAdditions': 203},
#  {'number': 151150,
#   'endoMultiplications': 459,
#   'endoAddition': 181,
#   'weierAdditions': 178,
#   'weierMultiplications': 428,
#   'montAdditions': 174,
#   'montMultiplications': 192,
#   'hadanoAdditions': 250,
#   'hadanoMultiplications': 486,
#   'edwardsAdditions': 196},
#  {'number': 726598,
#   'endoMultiplications': 534,
#   'endoAddition': 209,
#   'weierAdditions': 183,
#   'weierMultiplications': 446,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 263,
#   'hadanoMultiplications': 502,
#   'edwardsAdditions': 203},
#  {'number': 653294,
#   'endoMultiplications': 557,
#   'endoAddition': 221,
#   'weierAdditions': 225,
#   'weierMultiplications': 530,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 305,
#   'hadanoMultiplications': 610,
#   'edwardsAdditions': 245},
#  {'number': 996128,
#   'endoMultiplications': 570,
#   'endoAddition': 227,
#   'weierAdditions': 183,
#   'weierMultiplications': 446,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 263,
#   'hadanoMultiplications': 502,
#   'edwardsAdditions': 203},
#  {'number': 519094,
#   'endoMultiplications': 521,
#   'endoAddition': 202,
#   'weierAdditions': 212,
#   'weierMultiplications': 500,
#   'montAdditions': 184,
#   'montMultiplications': 203,
#   'hadanoAdditions': 288,
#   'hadanoMultiplications': 575,
#   'edwardsAdditions': 231},
#  {'number': 935271,
#   'endoMultiplications': 552,
#   'endoAddition': 218,
#   'weierAdditions': 197,
#   'weierMultiplications': 474,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 277,
#   'hadanoMultiplications': 538,
#   'edwardsAdditions': 217},
#  {'number': 554340,
#   'endoMultiplications': 521,
#   'endoAddition': 205,
#   'weierAdditions': 183,
#   'weierMultiplications': 446,
#   'montAdditions': 194,
#   'montMultiplications': 214,
#   'hadanoAdditions': 263,
#   'hadanoMultiplications': 502,
#   'edwardsAdditions': 203},
#  {'number': 153438,
#   'endoMultiplications': 495,
#   'endoAddition': 196,
#   'weierAdditions': 185,
#   'weierMultiplications': 442,
#   'montAdditions': 174,
#   'montMultiplications': 192,
#   'hadanoAdditions': 257,
#   'hadanoMultiplications': 504,
#   'edwardsAdditions': 203},
#  {'number': 360611,
#   'endoMultiplications': 454,
#   'endoAddition': 176,
#   'weierAdditions': 163,
#   'weierMultiplications': 402,
#   'montAdditions': 184,
#   'montMultiplications': 203,
#   'hadanoAdditions': 239,
#   'hadanoMultiplications': 449,
#   'edwardsAdditions': 182},
#  {'number': 321432,
#   'endoMultiplications': 508,
#   'endoAddition': 200,
#   'weierAdditions': 184,
#   'weierMultiplications': 444,
#   'montAdditions': 184,
#   'montMultiplications': 203,
#   'hadanoAdditions': 260,
#   'hadanoMultiplications': 503,
#   'edwardsAdditions': 203},
#  {'number': 1260275,
#   'endoMultiplications': 565,
#   'endoAddition': 223,
#   'weierAdditions': 217,
#   'weierMultiplications': 518,
#   'montAdditions': 204,
#   'montMultiplications': 225,
#   'hadanoAdditions': 301,
#   'hadanoMultiplications': 591,
#   'edwardsAdditions': 238},
#  {'number': 6020195,
#   'endoMultiplications': 627,
#   'endoAddition': 248,
#   'weierAdditions': 236,
#   'weierMultiplications': 564,
#   'montAdditions': 224,
#   'montMultiplications': 247,
#   'hadanoAdditions': 328,
#   'hadanoMultiplications': 643,
#   'edwardsAdditions': 259},
#  {'number': 3824674,
#   'endoMultiplications': 681,
#   'endoAddition': 269,
#   'weierAdditions': 202,
#   'weierMultiplications': 492,
#   'montAdditions': 214,
#   'montMultiplications': 236,
#   'hadanoAdditions': 290,
#   'hadanoMultiplications': 554,
#   'edwardsAdditions': 224},
#  {'number': 5143701,
#   'endoMultiplications': 591,
#   'endoAddition': 230,
#   'weierAdditions': 229,
#   'weierMultiplications': 550,
#   'montAdditions': 224,
#   'montMultiplications': 247,
#   'hadanoAdditions': 321,
#   'hadanoMultiplications': 625,
#   'edwardsAdditions': 252},
#  {'number': 2253062,
#   'endoMultiplications': 632,
#   'endoAddition': 251,
#   'weierAdditions': 181,
#   'weierMultiplications': 450,
#   'montAdditions': 214,
#   'montMultiplications': 236,
#   'hadanoAdditions': 269,
#   'hadanoMultiplications': 500,
#   'edwardsAdditions': 203},
#  {'number': 2181192,
#   'endoMultiplications': 560,
#   'endoAddition': 220,
#   'weierAdditions': 174,
#   'weierMultiplications': 436,
#   'montAdditions': 214,
#   'montMultiplications': 236,
#   'hadanoAdditions': 262,
#   'hadanoMultiplications': 482,
#   'edwardsAdditions': 196},
#  {'number': 2992773,
#   'endoMultiplications': 578,
#   'endoAddition': 225,
#   'weierAdditions': 209,
#   'weierMultiplications': 506,
#   'montAdditions': 214,
#   'montMultiplications': 236,
#   'hadanoAdditions': 297,
#   'hadanoMultiplications': 572,
#   'edwardsAdditions': 231},
#  {'number': 2435112,
#   'endoMultiplications': 596,
#   'endoAddition': 235,
#   'weierAdditions': 181,
#   'weierMultiplications': 450,
#   'montAdditions': 214,
#   'montMultiplications': 236,
#   'hadanoAdditions': 269,
#   'hadanoMultiplications': 500,
#   'edwardsAdditions': 203},
#  {'number': 8410659,
#   'endoMultiplications': 676,
#   'endoAddition': 268,
#   'weierAdditions': 200,
#   'weierMultiplications': 496,
#   'montAdditions': 234,
#   'montMultiplications': 258,
#   'hadanoAdditions': 296,
#   'hadanoMultiplications': 552,
#   'edwardsAdditions': 224},
#  {'number': 7449259,
#   'endoMultiplications': 640,
#   'endoAddition': 253,
#   'weierAdditions': 229,
#   'weierMultiplications': 550,
#   'montAdditions': 224,
#   'montMultiplications': 247,
#   'hadanoAdditions': 321,
#   'hadanoMultiplications': 625,
#   'edwardsAdditions': 252},
#  {'number': 8155556,
#   'endoMultiplications': 586,
#   'endoAddition': 232,
#   'weierAdditions': 222,
#   'weierMultiplications': 536,
#   'montAdditions': 224,
#   'montMultiplications': 247,
#   'hadanoAdditions': 314,
#   'hadanoMultiplications': 607,
#   'edwardsAdditions': 245},
#  {'number': 7156590,
#   'endoMultiplications': 622,
#   'endoAddition': 244,
#   'weierAdditions': 236,
#   'weierMultiplications': 564,
#   'montAdditions': 224,
#   'montMultiplications': 247,
#   'hadanoAdditions': 328,
#   'hadanoMultiplications': 643,
#   'edwardsAdditions': 259},
#  {'number': 9258348,
#   'endoMultiplications': 658,
#   'endoAddition': 260,
#   'weierAdditions': 221,
#   'weierMultiplications': 538,
#   'montAdditions': 234,
#   'montMultiplications': 258,
#   'hadanoAdditions': 317,
#   'hadanoMultiplications': 606,
#   'edwardsAdditions': 245},
#  {'number': 3944068,
#   'endoMultiplications': 681,
#   'endoAddition': 268,
#   'weierAdditions': 202,
#   'weierMultiplications': 492,
#   'montAdditions': 214,
#   'montMultiplications': 236,
#   'hadanoAdditions': 290,
#   'hadanoMultiplications': 554,
#   'edwardsAdditions': 224},
#  {'number': 1633950,
#   'endoMultiplications': 511,
#   'endoAddition': 201,
#   'weierAdditions': 217,
#   'weierMultiplications': 518,
#   'montAdditions': 204,
#   'montMultiplications': 225,
#   'hadanoAdditions': 301,
#   'hadanoMultiplications': 591,
#   'edwardsAdditions': 238},
#  {'number': 1294741,
#   'endoMultiplications': 565,
#   'endoAddition': 224,
#   'weierAdditions': 196,
#   'weierMultiplications': 476,
#   'montAdditions': 204,
#   'montMultiplications': 225,
#   'hadanoAdditions': 280,
#   'hadanoMultiplications': 537,
#   'edwardsAdditions': 217},
#  {'number': 7631221,
#   'endoMultiplications': 676,
#   'endoAddition': 269,
#   'weierAdditions': 229,
#   'weierMultiplications': 550,
#   'montAdditions': 224,
#   'montMultiplications': 247,
#   'hadanoAdditions': 321,
#   'hadanoMultiplications': 625,
#   'edwardsAdditions': 252},
#  {'number': 8973826,
#   'endoMultiplications': 622,
#   'endoAddition': 244,
#   'weierAdditions': 207,
#   'weierMultiplications': 510,
#   'montAdditions': 234,
#   'montMultiplications': 258,
#   'hadanoAdditions': 303,
#   'hadanoMultiplications': 570,
#   'edwardsAdditions': 231},
#  {'number': 1112869,
#   'endoMultiplications': 552,
#   'endoAddition': 217,
#   'weierAdditions': 203,
#   'weierMultiplications': 490,
#   'montAdditions': 204,
#   'montMultiplications': 225,
#   'hadanoAdditions': 287,
#   'hadanoMultiplications': 555,
#   'edwardsAdditions': 224},
#  {'number': 2391154,
#   'endoMultiplications': 632,
#   'endoAddition': 249,
#   'weierAdditions': 209,
#   'weierMultiplications': 506,
#   'montAdditions': 214,
#   'montMultiplications': 236,
#   'hadanoAdditions': 297,
#   'hadanoMultiplications': 572,
#   'edwardsAdditions': 231},
#  {'number': 13516581,
#   'endoMultiplications': 653,
#   'endoAddition': 259,
#   'weierAdditions': 242,
#   'weierMultiplications': 580,
#   'montAdditions': 234,
#   'montMultiplications': 258,
#   'hadanoAdditions': 338,
#   'hadanoMultiplications': 660,
#   'edwardsAdditions': 266},
#  {'number': 52178649,
#   'endoMultiplications': 679,
#   'endoAddition': 269,
#   'weierAdditions': 254,
#   'weierMultiplications': 612,
#   'montAdditions': 254,
#   'montMultiplications': 280,
#   'hadanoAdditions': 358,
#   'hadanoMultiplications': 694,
#   'edwardsAdditions': 280},
#  {'number': 10191418,
#   'endoMultiplications': 622,
#   'endoAddition': 246,
#   'weierAdditions': 221,
#   'weierMultiplications': 538,
#   'montAdditions': 234,
#   'montMultiplications': 258,
#   'hadanoAdditions': 317,
#   'hadanoMultiplications': 606,
#   'edwardsAdditions': 245},
#  {'number': 15774460,
#   'endoMultiplications': 671,
#   'endoAddition': 265,
#   'weierAdditions': 242,
#   'weierMultiplications': 580,
#   'montAdditions': 234,
#   'montMultiplications': 258,
#   'hadanoAdditions': 338,
#   'hadanoMultiplications': 660,
#   'edwardsAdditions': 266},
#  {'number': 30732734,
#   'endoMultiplications': 720,
#   'endoAddition': 284,
#   'weierAdditions': 262,
#   'weierMultiplications': 624,
#   'montAdditions': 244,
#   'montMultiplications': 269,
#   'hadanoAdditions': 362,
#   'hadanoMultiplications': 713,
#   'edwardsAdditions': 287},
#  {'number': 73166099,
#   'endoMultiplications': 692,
#   'endoAddition': 273,
#   'weierAdditions': 253,
#   'weierMultiplications': 614,
#   'montAdditions': 264,
#   'montMultiplications': 291,
#   'hadanoAdditions': 361,
#   'hadanoMultiplications': 693,
#   'edwardsAdditions': 280},
#  {'number': 44718899,
#   'endoMultiplications': 679,
#   'endoAddition': 268,
#   'weierAdditions': 254,
#   'weierMultiplications': 612,
#   'montAdditions': 254,
#   'montMultiplications': 280,
#   'hadanoAdditions': 358,
#   'hadanoMultiplications': 694,
#   'edwardsAdditions': 280},
#  {'number': 52134953,
#   'endoMultiplications': 715,
#   'endoAddition': 284,
#   'weierAdditions': 233,
#   'weierMultiplications': 570,
#   'montAdditions': 254,
#   'montMultiplications': 280,
#   'hadanoAdditions': 337,
#   'hadanoMultiplications': 640,
#   'edwardsAdditions': 259},
#  {'number': 27602898,
#   'endoMultiplications': 684,
#   'endoAddition': 267,
#   'weierAdditions': 248,
#   'weierMultiplications': 596,
#   'montAdditions': 244,
#   'montMultiplications': 269,
#   'hadanoAdditions': 348,
#   'hadanoMultiplications': 677,
#   'edwardsAdditions': 273},
#  {'number': 18473624,
#   'endoMultiplications': 635,
#   'endoAddition': 250,
#   'weierAdditions': 227,
#   'weierMultiplications': 554,
#   'montAdditions': 244,
#   'montMultiplications': 269,
#   'hadanoAdditions': 327,
#   'hadanoMultiplications': 623,
#   'edwardsAdditions': 252},
#  {'number': 44891137,
#   'endoMultiplications': 679,
#   'endoAddition': 267,
#   'weierAdditions': 240,
#   'weierMultiplications': 584,
#   'montAdditions': 254,
#   'montMultiplications': 280,
#   'hadanoAdditions': 344,
#   'hadanoMultiplications': 658,
#   'edwardsAdditions': 266},
#  {'number': 59125922,
#   'endoMultiplications': 710,
#   'endoAddition': 281,
#   'weierAdditions': 226,
#   'weierMultiplications': 556,
#   'montAdditions': 254,
#   'montMultiplications': 280,
#   'hadanoAdditions': 330,
#   'hadanoMultiplications': 622,
#   'edwardsAdditions': 252},
#  {'number': 69278279,
#   'endoMultiplications': 764,
#   'endoAddition': 305,
#   'weierAdditions': 232,
#   'weierMultiplications': 572,
#   'montAdditions': 264,
#   'montMultiplications': 291,
#   'hadanoAdditions': 340,
#   'hadanoMultiplications': 639,
#   'edwardsAdditions': 259},
#  {'number': 89995774,
#   'endoMultiplications': 710,
#   'endoAddition': 279,
#   'weierAdditions': 288,
#   'weierMultiplications': 684,
#   'montAdditions': 264,
#   'montMultiplications': 291,
#   'hadanoAdditions': 396,
#   'hadanoMultiplications': 783,
#   'edwardsAdditions': 315},
#  {'number': 49555091,
#   'endoMultiplications': 715,
#   'endoAddition': 285,
#   'weierAdditions': 247,
#   'weierMultiplications': 598,
#   'montAdditions': 254,
#   'montMultiplications': 280,
#   'hadanoAdditions': 351,
#   'hadanoMultiplications': 676,
#   'edwardsAdditions': 273},
#  {'number': 30063433,
#   'endoMultiplications': 702,
#   'endoAddition': 277,
#   'weierAdditions': 248,
#   'weierMultiplications': 596,
#   'montAdditions': 244,
#   'montMultiplications': 269,
#   'hadanoAdditions': 348,
#   'hadanoMultiplications': 677,
#   'edwardsAdditions': 273},
#  {'number': 47623887,
#   'endoMultiplications': 643,
#   'endoAddition': 251,
#   'weierAdditions': 275,
#   'weierMultiplications': 654,
#   'montAdditions': 254,
#   'montMultiplications': 280,
#   'hadanoAdditions': 379,
#   'hadanoMultiplications': 748,
#   'edwardsAdditions': 301},
#  {'number': 90922785,
#   'endoMultiplications': 692,
#   'endoAddition': 270,
#   'weierAdditions': 267,
#   'weierMultiplications': 642,
#   'montAdditions': 264,
#   'montMultiplications': 291,
#   'hadanoAdditions': 375,
#   'hadanoMultiplications': 729,
#   'edwardsAdditions': 294},
#  {'number': 21882492,
#   'endoMultiplications': 720,
#   'endoAddition': 287,
#   'weierAdditions': 255,
#   'weierMultiplications': 610,
#   'montAdditions': 244,
#   'montMultiplications': 269,
#   'hadanoAdditions': 355,
#   'hadanoMultiplications': 695,
#   'edwardsAdditions': 280},
#  {'number': 10106340,
#   'endoMultiplications': 586,
#   'endoAddition': 230,
#   'weierAdditions': 228,
#   'weierMultiplications': 552,
#   'montAdditions': 234,
#   'montMultiplications': 258,
#   'hadanoAdditions': 324,
#   'hadanoMultiplications': 624,
#   'edwardsAdditions': 252},
#  {'number': 48770501,
#   'endoMultiplications': 715,
#   'endoAddition': 282,
#   'weierAdditions': 247,
#   'weierMultiplications': 598,
#   'montAdditions': 254,
#   'montMultiplications': 280,
#   'hadanoAdditions': 351,
#   'hadanoMultiplications': 676,
#   'edwardsAdditions': 273},
#  {'number': 92047531,
#   'endoMultiplications': 800,
#   'endoAddition': 320,
#   'weierAdditions': 260,
#   'weierMultiplications': 628,
#   'montAdditions': 264,
#   'montMultiplications': 291,
#   'hadanoAdditions': 368,
#   'hadanoMultiplications': 711,
#   'edwardsAdditions': 287},
#  {'number': 78596229,
#   'endoMultiplications': 728,
#   'endoAddition': 287,
#   'weierAdditions': 246,
#   'weierMultiplications': 600,
#   'montAdditions': 264,
#   'montMultiplications': 291,
#   'hadanoAdditions': 354,
#   'hadanoMultiplications': 675,
#   'edwardsAdditions': 273},
#  {'number': 882254877,
#   'endoMultiplications': 852,
#   'endoAddition': 339,
#   'weierAdditions': 271,
#   'weierMultiplications': 662,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 391,
#   'hadanoMultiplications': 744,
#   'edwardsAdditions': 301},
#  {'number': 817063905,
#   'endoMultiplications': 744,
#   'endoAddition': 292,
#   'weierAdditions': 292,
#   'weierMultiplications': 704,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 412,
#   'hadanoMultiplications': 798,
#   'edwardsAdditions': 322},
#  {'number': 369486820,
#   'endoMultiplications': 749,
#   'endoAddition': 295,
#   'weierAdditions': 279,
#   'weierMultiplications': 674,
#   'montAdditions': 284,
#   'montMultiplications': 313,
#   'hadanoAdditions': 395,
#   'hadanoMultiplications': 763,
#   'edwardsAdditions': 308},
#  {'number': 639388871,
#   'endoMultiplications': 744,
#   'endoAddition': 291,
#   'weierAdditions': 278,
#   'weierMultiplications': 676,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 398,
#   'hadanoMultiplications': 762,
#   'edwardsAdditions': 308},
#  {'number': 596878914,
#   'endoMultiplications': 834,
#   'endoAddition': 331,
#   'weierAdditions': 271,
#   'weierMultiplications': 662,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 391,
#   'hadanoMultiplications': 744,
#   'edwardsAdditions': 301},
#  {'number': 646457352,
#   'endoMultiplications': 762,
#   'endoAddition': 298,
#   'weierAdditions': 236,
#   'weierMultiplications': 592,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 356,
#   'hadanoMultiplications': 654,
#   'edwardsAdditions': 266},
#  {'number': 930787397,
#   'endoMultiplications': 829,
#   'endoAddition': 329,
#   'weierAdditions': 292,
#   'weierMultiplications': 704,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 412,
#   'hadanoMultiplications': 798,
#   'edwardsAdditions': 322},
#  {'number': 460831012,
#   'endoMultiplications': 785,
#   'endoAddition': 310,
#   'weierAdditions': 293,
#   'weierMultiplications': 702,
#   'montAdditions': 284,
#   'montMultiplications': 313,
#   'hadanoAdditions': 409,
#   'hadanoMultiplications': 799,
#   'edwardsAdditions': 322},
#  {'number': 175879939,
#   'endoMultiplications': 754,
#   'endoAddition': 298,
#   'weierAdditions': 280,
#   'weierMultiplications': 672,
#   'montAdditions': 274,
#   'montMultiplications': 302,
#   'hadanoAdditions': 392,
#   'hadanoMultiplications': 764,
#   'edwardsAdditions': 308},
#  {'number': 381553625,
#   'endoMultiplications': 767,
#   'endoAddition': 302,
#   'weierAdditions': 293,
#   'weierMultiplications': 702,
#   'montAdditions': 284,
#   'montMultiplications': 313,
#   'hadanoAdditions': 409,
#   'hadanoMultiplications': 799,
#   'edwardsAdditions': 322},
#  {'number': 385837283,
#   'endoMultiplications': 731,
#   'endoAddition': 290,
#   'weierAdditions': 307,
#   'weierMultiplications': 730,
#   'montAdditions': 284,
#   'montMultiplications': 313,
#   'hadanoAdditions': 423,
#   'hadanoMultiplications': 835,
#   'edwardsAdditions': 336},
#  {'number': 975406613,
#   'endoMultiplications': 793,
#   'endoAddition': 314,
#   'weierAdditions': 271,
#   'weierMultiplications': 662,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 391,
#   'hadanoMultiplications': 744,
#   'edwardsAdditions': 301},
#  {'number': 218557335,
#   'endoMultiplications': 754,
#   'endoAddition': 298,
#   'weierAdditions': 280,
#   'weierMultiplications': 672,
#   'montAdditions': 274,
#   'montMultiplications': 302,
#   'hadanoAdditions': 392,
#   'hadanoMultiplications': 764,
#   'edwardsAdditions': 308},
#  {'number': 278655023,
#   'endoMultiplications': 790,
#   'endoAddition': 313,
#   'weierAdditions': 279,
#   'weierMultiplications': 674,
#   'montAdditions': 284,
#   'montMultiplications': 313,
#   'hadanoAdditions': 395,
#   'hadanoMultiplications': 763,
#   'edwardsAdditions': 308},
#  {'number': 522492216,
#   'endoMultiplications': 798,
#   'endoAddition': 315,
#   'weierAdditions': 272,
#   'weierMultiplications': 660,
#   'montAdditions': 284,
#   'montMultiplications': 313,
#   'hadanoAdditions': 388,
#   'hadanoMultiplications': 745,
#   'edwardsAdditions': 301},
#  {'number': 196275577,
#   'endoMultiplications': 790,
#   'endoAddition': 314,
#   'weierAdditions': 294,
#   'weierMultiplications': 700,
#   'montAdditions': 274,
#   'montMultiplications': 302,
#   'hadanoAdditions': 406,
#   'hadanoMultiplications': 800,
#   'edwardsAdditions': 322},
#  {'number': 179591763,
#   'endoMultiplications': 790,
#   'endoAddition': 315,
#   'weierAdditions': 266,
#   'weierMultiplications': 644,
#   'montAdditions': 274,
#   'montMultiplications': 302,
#   'hadanoAdditions': 378,
#   'hadanoMultiplications': 728,
#   'edwardsAdditions': 294},
#  {'number': 721534875,
#   'endoMultiplications': 780,
#   'endoAddition': 308,
#   'weierAdditions': 299,
#   'weierMultiplications': 718,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 419,
#   'hadanoMultiplications': 816,
#   'edwardsAdditions': 329},
#  {'number': 518577777,
#   'endoMultiplications': 744,
#   'endoAddition': 290,
#   'weierAdditions': 300,
#   'weierMultiplications': 716,
#   'montAdditions': 284,
#   'montMultiplications': 313,
#   'hadanoAdditions': 416,
#   'hadanoMultiplications': 817,
#   'edwardsAdditions': 329},
#  {'number': 451411702,
#   'endoMultiplications': 785,
#   'endoAddition': 309,
#   'weierAdditions': 328,
#   'weierMultiplications': 772,
#   'montAdditions': 284,
#   'montMultiplications': 313,
#   'hadanoAdditions': 444,
#   'hadanoMultiplications': 889,
#   'edwardsAdditions': 357},
#  {'number': 245801131,
#   'endoMultiplications': 754,
#   'endoAddition': 294,
#   'weierAdditions': 266,
#   'weierMultiplications': 644,
#   'montAdditions': 274,
#   'montMultiplications': 302,
#   'hadanoAdditions': 378,
#   'hadanoMultiplications': 728,
#   'edwardsAdditions': 294},
#  {'number': 901714218,
#   'endoMultiplications': 811,
#   'endoAddition': 321,
#   'weierAdditions': 292,
#   'weierMultiplications': 704,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 412,
#   'hadanoMultiplications': 798,
#   'edwardsAdditions': 322},
#  {'number': 174505841,
#   'endoMultiplications': 718,
#   'endoAddition': 284,
#   'weierAdditions': 287,
#   'weierMultiplications': 686,
#   'montAdditions': 274,
#   'montMultiplications': 302,
#   'hadanoAdditions': 399,
#   'hadanoMultiplications': 782,
#   'edwardsAdditions': 315},
#  {'number': 768110852,
#   'endoMultiplications': 726,
#   'endoAddition': 289,
#   'weierAdditions': 264,
#   'weierMultiplications': 648,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 384,
#   'hadanoMultiplications': 726,
#   'edwardsAdditions': 294},
#  {'number': 252623362,
#   'endoMultiplications': 772,
#   'endoAddition': 304,
#   'weierAdditions': 259,
#   'weierMultiplications': 630,
#   'montAdditions': 274,
#   'montMultiplications': 302,
#   'hadanoAdditions': 371,
#   'hadanoMultiplications': 710,
#   'edwardsAdditions': 287},
#  {'number': 647170178,
#   'endoMultiplications': 762,
#   'endoAddition': 301,
#   'weierAdditions': 250,
#   'weierMultiplications': 620,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 370,
#   'hadanoMultiplications': 690,
#   'edwardsAdditions': 280},
#  {'number': 432070357,
#   'endoMultiplications': 695,
#   'endoAddition': 272,
#   'weierAdditions': 286,
#   'weierMultiplications': 688,
#   'montAdditions': 284,
#   'montMultiplications': 313,
#   'hadanoAdditions': 402,
#   'hadanoMultiplications': 781,
#   'edwardsAdditions': 315},
#  {'number': 2131889636,
#   'endoMultiplications': 896,
#   'endoAddition': 351,
#   'weierAdditions': 298,
#   'weierMultiplications': 720,
#   'montAdditions': 304,
#   'montMultiplications': 335,
#   'hadanoAdditions': 422,
#   'hadanoMultiplications': 815,
#   'edwardsAdditions': 329},
#  {'number': 9425479862,
#   'endoMultiplications': 791,
#   'endoAddition': 311,
#   'weierAdditions': 323,
#   'weierMultiplications': 782,
#   'montAdditions': 334,
#   'montMultiplications': 368,
#   'hadanoAdditions': 459,
#   'hadanoMultiplications': 884,
#   'edwardsAdditions': 357},
#  {'number': 2019471840,
#   'endoMultiplications': 824,
#   'endoAddition': 327,
#   'weierAdditions': 298,
#   'weierMultiplications': 720,
#   'montAdditions': 304,
#   'montMultiplications': 335,
#   'hadanoAdditions': 422,
#   'hadanoMultiplications': 815,
#   'edwardsAdditions': 329},
#  {'number': 4975546881,
#   'endoMultiplications': 868,
#   'endoAddition': 346,
#   'weierAdditions': 268,
#   'weierMultiplications': 668,
#   'montAdditions': 324,
#   'montMultiplications': 357,
#   'hadanoAdditions': 400,
#   'hadanoMultiplications': 741,
#   'edwardsAdditions': 301},
#  {'number': 6198238179,
#   'endoMultiplications': 760,
#   'endoAddition': 298,
#   'weierAdditions': 331,
#   'weierMultiplications': 794,
#   'montAdditions': 324,
#   'montMultiplications': 357,
#   'hadanoAdditions': 463,
#   'hadanoMultiplications': 903,
#   'edwardsAdditions': 364},
#  {'number': 8761592747,
#   'endoMultiplications': 917,
#   'endoAddition': 361,
#   'weierAdditions': 323,
#   'weierMultiplications': 782,
#   'montAdditions': 334,
#   'montMultiplications': 368,
#   'hadanoAdditions': 459,
#   'hadanoMultiplications': 884,
#   'edwardsAdditions': 357},
#  {'number': 1025927440,
#   'endoMultiplications': 847,
#   'endoAddition': 335,
#   'weierAdditions': 271,
#   'weierMultiplications': 662,
#   'montAdditions': 294,
#   'montMultiplications': 324,
#   'hadanoAdditions': 391,
#   'hadanoMultiplications': 744,
#   'edwardsAdditions': 301},
#  {'number': 7831049054,
#   'endoMultiplications': 922,
#   'endoAddition': 368,
#   'weierAdditions': 317,
#   'weierMultiplications': 766,
#   'montAdditions': 324,
#   'montMultiplications': 357,
#   'hadanoAdditions': 449,
#   'hadanoMultiplications': 867,
#   'edwardsAdditions': 350},
#  {'number': 8035885989,
#   'endoMultiplications': 845,
#   'endoAddition': 334,
#   'weierAdditions': 352,
#   'weierMultiplications': 836,
#   'montAdditions': 324,
#   'montMultiplications': 357,
#   'hadanoAdditions': 484,
#   'hadanoMultiplications': 957,
#   'edwardsAdditions': 385},
#  {'number': 5559426886,
#   'endoMultiplications': 850,
#   'endoAddition': 336,
#   'weierAdditions': 324,
#   'weierMultiplications': 780,
#   'montAdditions': 324,
#   'montMultiplications': 357,
#   'hadanoAdditions': 456,
#   'hadanoMultiplications': 885,
#   'edwardsAdditions': 357},
#  {'number': 8817657061,
#   'endoMultiplications': 917,
#   'endoAddition': 362,
#   'weierAdditions': 309,
#   'weierMultiplications': 754,
#   'montAdditions': 334,
#   'montMultiplications': 368,
#   'hadanoAdditions': 445,
#   'hadanoMultiplications': 848,
#   'edwardsAdditions': 343},
#  {'number': 1327726519,
#   'endoMultiplications': 829,
#   'endoAddition': 328,
#   'weierAdditions': 333,
#   'weierMultiplications': 790,
#   'montAdditions': 304,
#   'montMultiplications': 335,
#   'hadanoAdditions': 457,
#   'hadanoMultiplications': 905,
#   'edwardsAdditions': 364},
#  {'number': 5855642704,
#   'endoMultiplications': 886,
#   'endoAddition': 350,
#   'weierAdditions': 275,
#   'weierMultiplications': 682,
#   'montAdditions': 324,
#   'montMultiplications': 357,
#   'hadanoAdditions': 407,
#   'hadanoMultiplications': 759,
#   'edwardsAdditions': 308},
#  {'number': 3337538701,
#   'endoMultiplications': 891,
#   'endoAddition': 352,
#   'weierAdditions': 318,
#   'weierMultiplications': 764,
#   'montAdditions': 314,
#   'montMultiplications': 346,
#   'hadanoAdditions': 446,
#   'hadanoMultiplications': 868,
#   'edwardsAdditions': 350},
#  {'number': 3077949993,
#   'endoMultiplications': 819,
#   'endoAddition': 322,
#   'weierAdditions': 318,
#   'weierMultiplications': 764,
#   'montAdditions': 314,
#   'montMultiplications': 346,
#   'hadanoAdditions': 446,
#   'hadanoMultiplications': 868,
#   'edwardsAdditions': 350},
#  {'number': 2240126422,
#   'endoMultiplications': 860,
#   'endoAddition': 335,
#   'weierAdditions': 304,
#   'weierMultiplications': 736,
#   'montAdditions': 314,
#   'montMultiplications': 346,
#   'hadanoAdditions': 432,
#   'hadanoMultiplications': 832,
#   'edwardsAdditions': 336},
#  {'number': 1982643878,
#   'endoMultiplications': 860,
#   'endoAddition': 341,
#   'weierAdditions': 312,
#   'weierMultiplications': 748,
#   'montAdditions': 304,
#   'montMultiplications': 335,
#   'hadanoAdditions': 436,
#   'hadanoMultiplications': 851,
#   'edwardsAdditions': 343},
#  {'number': 2870038947,
#   'endoMultiplications': 855,
#   'endoAddition': 338,
#   'weierAdditions': 290,
#   'weierMultiplications': 708,
#   'montAdditions': 314,
#   'montMultiplications': 346,
#   'hadanoAdditions': 418,
#   'hadanoMultiplications': 796,
#   'edwardsAdditions': 322},
#  {'number': 7633874544,
#   'endoMultiplications': 850,
#   'endoAddition': 337,
#   'weierAdditions': 310,
#   'weierMultiplications': 752,
#   'montAdditions': 324,
#   'montMultiplications': 357,
#   'hadanoAdditions': 442,
#   'hadanoMultiplications': 849,
#   'edwardsAdditions': 343},
#  {'number': 4176629318,
#   'endoMultiplications': 873,
#   'endoAddition': 348,
#   'weierAdditions': 311,
#   'weierMultiplications': 750,
#   'montAdditions': 314,
#   'montMultiplications': 346,
#   'hadanoAdditions': 439,
#   'hadanoMultiplications': 850,
#   'edwardsAdditions': 343},
#  {'number': 8625514810,
#   'endoMultiplications': 899,
#   'endoAddition': 358,
#   'weierAdditions': 309,
#   'weierMultiplications': 754,
#   'montAdditions': 334,
#   'montMultiplications': 368,
#   'hadanoAdditions': 445,
#   'hadanoMultiplications': 848,
#   'edwardsAdditions': 343},
#  {'number': 7873961273,
#   'endoMultiplications': 904,
#   'endoAddition': 365,
#   'weierAdditions': 324,
#   'weierMultiplications': 780,
#   'montAdditions': 324,
#   'montMultiplications': 357,
#   'hadanoAdditions': 456,
#   'hadanoMultiplications': 885,
#   'edwardsAdditions': 357},
#  {'number': 3632989699,
#   'endoMultiplications': 747,
#   'endoAddition': 291,
#   'weierAdditions': 276,
#   'weierMultiplications': 680,
#   'montAdditions': 314,
#   'montMultiplications': 346,
#   'hadanoAdditions': 404,
#   'hadanoMultiplications': 760,
#   'edwardsAdditions': 308},
#  {'number': 9769798617,
#   'endoMultiplications': 917,
#   'endoAddition': 362,
#   'weierAdditions': 323,
#   'weierMultiplications': 782,
#   'montAdditions': 334,
#   'montMultiplications': 368,
#   'hadanoAdditions': 459,
#   'hadanoMultiplications': 884,
#   'edwardsAdditions': 357},
#  {'number': 4289557269,
#   'endoMultiplications': 819,
#   'endoAddition': 324,
#   'weierAdditions': 339,
#   'weierMultiplications': 806,
#   'montAdditions': 314,
#   'montMultiplications': 346,
#   'hadanoAdditions': 467,
#   'hadanoMultiplications': 922,
#   'edwardsAdditions': 371},
#  {'number': 8797868294,
#   'endoMultiplications': 863,
#   'endoAddition': 339,
#   'weierAdditions': 288,
#   'weierMultiplications': 712,
#   'montAdditions': 334,
#   'montMultiplications': 368,
#   'hadanoAdditions': 424,
#   'hadanoMultiplications': 794,
#   'edwardsAdditions': 322},
#  {'number': 3358320089,
#   'endoMultiplications': 783,
#   'endoAddition': 307,
#   'weierAdditions': 311,
#   'weierMultiplications': 750,
#   'montAdditions': 314,
#   'montMultiplications': 346,
#   'hadanoAdditions': 439,
#   'hadanoMultiplications': 850,
#   'edwardsAdditions': 343},
#  {'number': 5605581739,
#   'endoMultiplications': 904,
#   'endoAddition': 360,
#   'weierAdditions': 324,
#   'weierMultiplications': 780,
#   'montAdditions': 324,
#   'montMultiplications': 357,
#   'hadanoAdditions': 456,
#   'hadanoMultiplications': 885,
#   'edwardsAdditions': 357},
#  {'number': 7632420285,
#   'endoMultiplications': 868,
#   'endoAddition': 344,
#   'weierAdditions': 359,
#   'weierMultiplications': 850,
#   'montAdditions': 324,
#   'montMultiplications': 357,
#   'hadanoAdditions': 491,
#   'hadanoMultiplications': 975,
#   'edwardsAdditions': 392},
#  {'number': 8664453490,
#   'endoMultiplications': 935,
#   'endoAddition': 371,
#   'weierAdditions': 288,
#   'weierMultiplications': 712,
#   'montAdditions': 334,
#   'montMultiplications': 368,
#   'hadanoAdditions': 424,
#   'hadanoMultiplications': 794,
#   'edwardsAdditions': 322},
#  {'number': 76625178933,
#   'endoMultiplications': 969,
#   'endoAddition': 382,
#   'weierAdditions': 369,
#   'weierMultiplications': 886,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 517,
#   'hadanoMultiplications': 1007,
#   'edwardsAdditions': 406},
#  {'number': 70651680877,
#   'endoMultiplications': 992,
#   'endoAddition': 394,
#   'weierAdditions': 341,
#   'weierMultiplications': 830,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 489,
#   'hadanoMultiplications': 935,
#   'edwardsAdditions': 378},
#  {'number': 60746443679,
#   'endoMultiplications': 992,
#   'endoAddition': 395,
#   'weierAdditions': 349,
#   'weierMultiplications': 842,
#   'montAdditions': 354,
#   'montMultiplications': 390,
#   'hadanoAdditions': 493,
#   'hadanoMultiplications': 954,
#   'edwardsAdditions': 385},
#  {'number': 79850413975,
#   'endoMultiplications': 933,
#   'endoAddition': 366,
#   'weierAdditions': 376,
#   'weierMultiplications': 900,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 524,
#   'hadanoMultiplications': 1025,
#   'edwardsAdditions': 413},
#  {'number': 50328067403,
#   'endoMultiplications': 992,
#   'endoAddition': 395,
#   'weierAdditions': 370,
#   'weierMultiplications': 884,
#   'montAdditions': 354,
#   'montMultiplications': 390,
#   'hadanoAdditions': 514,
#   'hadanoMultiplications': 1008,
#   'edwardsAdditions': 406},
#  {'number': 73984853776,
#   'endoMultiplications': 951,
#   'endoAddition': 377,
#   'weierAdditions': 341,
#   'weierMultiplications': 830,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 489,
#   'hadanoMultiplications': 935,
#   'edwardsAdditions': 378},
#  {'number': 16442837965,
#   'endoMultiplications': 894,
#   'endoAddition': 350,
#   'weierAdditions': 330,
#   'weierMultiplications': 796,
#   'montAdditions': 334,
#   'montMultiplications': 368,
#   'hadanoAdditions': 466,
#   'hadanoMultiplications': 902,
#   'edwardsAdditions': 364},
#  {'number': 73143097584,
#   'endoMultiplications': 951,
#   'endoAddition': 373,
#   'weierAdditions': 334,
#   'weierMultiplications': 816,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 482,
#   'hadanoMultiplications': 917,
#   'edwardsAdditions': 371},
#  {'number': 81285847527,
#   'endoMultiplications': 933,
#   'endoAddition': 368,
#   'weierAdditions': 362,
#   'weierMultiplications': 872,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 510,
#   'hadanoMultiplications': 989,
#   'edwardsAdditions': 399},
#  {'number': 23191716785,
#   'endoMultiplications': 966,
#   'endoAddition': 380,
#   'weierAdditions': 329,
#   'weierMultiplications': 798,
#   'montAdditions': 344,
#   'montMultiplications': 379,
#   'hadanoAdditions': 469,
#   'hadanoMultiplications': 901,
#   'edwardsAdditions': 364},
#  {'number': 60109358124,
#   'endoMultiplications': 902,
#   'endoAddition': 361,
#   'weierAdditions': 342,
#   'weierMultiplications': 828,
#   'montAdditions': 354,
#   'montMultiplications': 390,
#   'hadanoAdditions': 486,
#   'hadanoMultiplications': 936,
#   'edwardsAdditions': 378},
#  {'number': 33361670658,
#   'endoMultiplications': 925,
#   'endoAddition': 364,
#   'weierAdditions': 301,
#   'weierMultiplications': 742,
#   'montAdditions': 344,
#   'montMultiplications': 379,
#   'hadanoAdditions': 441,
#   'hadanoMultiplications': 829,
#   'edwardsAdditions': 336},
#  {'number': 23230157924,
#   'endoMultiplications': 876,
#   'endoAddition': 343,
#   'weierAdditions': 294,
#   'weierMultiplications': 728,
#   'montAdditions': 344,
#   'montMultiplications': 379,
#   'hadanoAdditions': 434,
#   'hadanoMultiplications': 811,
#   'edwardsAdditions': 329},
#  {'number': 40247742928,
#   'endoMultiplications': 925,
#   'endoAddition': 365,
#   'weierAdditions': 356,
#   'weierMultiplications': 856,
#   'montAdditions': 354,
#   'montMultiplications': 390,
#   'hadanoAdditions': 500,
#   'hadanoMultiplications': 972,
#   'edwardsAdditions': 392},
#  {'number': 69075491601,
#   'endoMultiplications': 956,
#   'endoAddition': 377,
#   'weierAdditions': 320,
#   'weierMultiplications': 788,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 468,
#   'hadanoMultiplications': 881,
#   'edwardsAdditions': 357},
#  {'number': 81830131929,
#   'endoMultiplications': 933,
#   'endoAddition': 369,
#   'weierAdditions': 355,
#   'weierMultiplications': 858,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 503,
#   'hadanoMultiplications': 971,
#   'edwardsAdditions': 392},
#  {'number': 93512288635,
#   'endoMultiplications': 933,
#   'endoAddition': 368,
#   'weierAdditions': 355,
#   'weierMultiplications': 858,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 503,
#   'hadanoMultiplications': 971,
#   'edwardsAdditions': 392},
#  {'number': 80509220625,
#   'endoMultiplications': 969,
#   'endoAddition': 384,
#   'weierAdditions': 362,
#   'weierMultiplications': 872,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 510,
#   'hadanoMultiplications': 989,
#   'edwardsAdditions': 399},
#  {'number': 12504868848,
#   'endoMultiplications': 899,
#   'endoAddition': 357,
#   'weierAdditions': 330,
#   'weierMultiplications': 796,
#   'montAdditions': 334,
#   'montMultiplications': 368,
#   'hadanoAdditions': 466,
#   'hadanoMultiplications': 902,
#   'edwardsAdditions': 364},
#  {'number': 84594508340,
#   'endoMultiplications': 1023,
#   'endoAddition': 409,
#   'weierAdditions': 341,
#   'weierMultiplications': 830,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 489,
#   'hadanoMultiplications': 935,
#   'edwardsAdditions': 378},
#  {'number': 35798450901,
#   'endoMultiplications': 907,
#   'endoAddition': 357,
#   'weierAdditions': 314,
#   'weierMultiplications': 772,
#   'montAdditions': 354,
#   'montMultiplications': 390,
#   'hadanoAdditions': 458,
#   'hadanoMultiplications': 864,
#   'edwardsAdditions': 350},
#  {'number': 58100154171,
#   'endoMultiplications': 884,
#   'endoAddition': 350,
#   'weierAdditions': 370,
#   'weierMultiplications': 884,
#   'montAdditions': 354,
#   'montMultiplications': 390,
#   'hadanoAdditions': 514,
#   'hadanoMultiplications': 1008,
#   'edwardsAdditions': 406},
#  {'number': 44694175693,
#   'endoMultiplications': 956,
#   'endoAddition': 375,
#   'weierAdditions': 398,
#   'weierMultiplications': 940,
#   'montAdditions': 354,
#   'montMultiplications': 390,
#   'hadanoAdditions': 542,
#   'hadanoMultiplications': 1080,
#   'edwardsAdditions': 434},
#  {'number': 12428077467,
#   'endoMultiplications': 917,
#   'endoAddition': 363,
#   'weierAdditions': 330,
#   'weierMultiplications': 796,
#   'montAdditions': 334,
#   'montMultiplications': 368,
#   'hadanoAdditions': 466,
#   'hadanoMultiplications': 902,
#   'edwardsAdditions': 364},
#  {'number': 99487170114,
#   'endoMultiplications': 915,
#   'endoAddition': 359,
#   'weierAdditions': 362,
#   'weierMultiplications': 872,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 510,
#   'hadanoMultiplications': 989,
#   'edwardsAdditions': 399},
#  {'number': 75125002468,
#   'endoMultiplications': 1023,
#   'endoAddition': 407,
#   'weierAdditions': 348,
#   'weierMultiplications': 844,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 496,
#   'hadanoMultiplications': 953,
#   'edwardsAdditions': 385},
#  {'number': 41375419684,
#   'endoMultiplications': 974,
#   'endoAddition': 385,
#   'weierAdditions': 321,
#   'weierMultiplications': 786,
#   'montAdditions': 354,
#   'montMultiplications': 390,
#   'hadanoAdditions': 465,
#   'hadanoMultiplications': 882,
#   'edwardsAdditions': 357},
#  {'number': 17900291829,
#   'endoMultiplications': 894,
#   'endoAddition': 352,
#   'weierAdditions': 336,
#   'weierMultiplications': 812,
#   'montAdditions': 344,
#   'montMultiplications': 379,
#   'hadanoAdditions': 476,
#   'hadanoMultiplications': 919,
#   'edwardsAdditions': 371},
#  {'number': 98706729179,
#   'endoMultiplications': 933,
#   'endoAddition': 366,
#   'weierAdditions': 369,
#   'weierMultiplications': 886,
#   'montAdditions': 364,
#   'montMultiplications': 401,
#   'hadanoAdditions': 517,
#   'hadanoMultiplications': 1007,
#   'edwardsAdditions': 406},
#  {'number': 60075778617,
#   'endoMultiplications': 992,
#   'endoAddition': 398,
#   'weierAdditions': 363,
#   'weierMultiplications': 870,
#   'montAdditions': 354,
#   'montMultiplications': 390,
#   'hadanoAdditions': 507,
#   'hadanoMultiplications': 990,
#   'edwardsAdditions': 399},
#  {'number': 33191286551,
# ...
#   'edwardsAdditions': 2583},
#  {'number': 662717283179605665190987869300764565601238078862201061409604295838161693558,
#   'endoMultiplications': 5983,
#   'endoAddition': 2357,
#   'weierAdditions': 2488,
#   'weierMultiplications': 5972,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3484,
#   'hadanoMultiplications': 6789,
#   'edwardsAdditions': 2737},
#  {'number': 514587792694206295749330733721950666464509263834086885934718528905505794309,
#   'endoMultiplications': 6132,
#   'endoAddition': 2428,
#   'weierAdditions': 2264,
#   'weierMultiplications': 5524,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3260,
#   'hadanoMultiplications': 6213,
#   'edwardsAdditions': 2513},
#  {'number': 441204833355614110795947766553340718760376023487164216989214292836809722588,
#   'endoMultiplications': 6078,
#   'endoAddition': 2396,
#   'weierAdditions': 2398,
#   'weierMultiplications': 5788,
#   'montAdditions': 2474,
#   'montMultiplications': 2722,
#   'hadanoAdditions': 3390,
#   'hadanoMultiplications': 6556,
#   'edwardsAdditions': 2646},
#  {'number': 669705275431821526869671235050623354840254285709925438523915376600625607222,
#   'endoMultiplications': 5983,
#   'endoAddition': 2365,
#   'weierAdditions': 2411,
#   'weierMultiplications': 5818,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3407,
#   'hadanoMultiplications': 6591,
#   'edwardsAdditions': 2660},
#  {'number': 623234986140319815902798775050731718759135228949814383717645275874248714771,
#   'endoMultiplications': 6109,
#   'endoAddition': 2411,
#   'weierAdditions': 2418,
#   'weierMultiplications': 5832,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3414,
#   'hadanoMultiplications': 6609,
#   'edwardsAdditions': 2667},
#  {'number': 874390855722733293633123174722124310772046582413368154779747667797958134909,
#   'endoMultiplications': 5929,
#   'endoAddition': 2341,
#   'weierAdditions': 2418,
#   'weierMultiplications': 5832,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3414,
#   'hadanoMultiplications': 6609,
#   'edwardsAdditions': 2667},
#  {'number': 849340479860963672877811625498740838197239253186852973680133362199916156483,
#   'endoMultiplications': 6073,
#   'endoAddition': 2402,
#   'weierAdditions': 2320,
#   'weierMultiplications': 5636,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3316,
#   'hadanoMultiplications': 6357,
#   'edwardsAdditions': 2569},
#  {'number': 646039479082695516693259012589075277959543451189922663139976727584987402196,
#   'endoMultiplications': 5911,
#   'endoAddition': 2322,
#   'weierAdditions': 2334,
#   'weierMultiplications': 5664,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3330,
#   'hadanoMultiplications': 6393,
#   'edwardsAdditions': 2583},
#  {'number': 926072397905757364292592175118109725592063281386776362814972751684158726979,
#   'endoMultiplications': 6073,
#   'endoAddition': 2402,
#   'weierAdditions': 2375,
#   'weierMultiplications': 5750,
#   'montAdditions': 2494,
#   'montMultiplications': 2744,
#   'hadanoAdditions': 3375,
#   'hadanoMultiplications': 6500,
#   'edwardsAdditions': 2625},
#  {'number': 472644385343394264483582472285910766402953831838831590739045015610833760320,
#   'endoMultiplications': 5970,
#   'endoAddition': 2349,
#   'weierAdditions': 2306,
#   'weierMultiplications': 5608,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3302,
#   'hadanoMultiplications': 6321,
#   'edwardsAdditions': 2555},
#  {'number': 568566631986347807827869182091239728531952225278762480472601206332176831969,
#   'endoMultiplications': 5988,
#   'endoAddition': 2362,
#   'weierAdditions': 2278,
#   'weierMultiplications': 5552,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3274,
#   'hadanoMultiplications': 6249,
#   'edwardsAdditions': 2527},
#  {'number': 757156316830458021350407998513449246744915054077959092838546621211015338743,
#   'endoMultiplications': 5965,
#   'endoAddition': 2353,
#   'weierAdditions': 2327,
#   'weierMultiplications': 5650,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3323,
#   'hadanoMultiplications': 6375,
#   'edwardsAdditions': 2576},
#  {'number': 862413972980950408581905531052059812711631468182347955283939530005138935621,
#   'endoMultiplications': 6001,
#   'endoAddition': 2365,
#   'weierAdditions': 2215,
#   'weierMultiplications': 5426,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3211,
#   'hadanoMultiplications': 6087,
#   'edwardsAdditions': 2464},
#  {'number': 769932606375666786325364023481513198451141660349418191996839355002659821954,
#   'endoMultiplications': 6163,
#   'endoAddition': 2432,
#   'weierAdditions': 2369,
#   'weierMultiplications': 5734,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3365,
#   'hadanoMultiplications': 6483,
#   'edwardsAdditions': 2618},
#  {'number': 513971199740245484624127374870802230185628358305005340676135582558105267701,
#   'endoMultiplications': 6168,
#   'endoAddition': 2435,
#   'weierAdditions': 2341,
#   'weierMultiplications': 5678,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3337,
#   'hadanoMultiplications': 6411,
#   'edwardsAdditions': 2590},
#  {'number': 851302004839564574350809894683233177239569077401652558186809831221915912724,
#   'endoMultiplications': 5983,
#   'endoAddition': 2356,
#   'weierAdditions': 2369,
#   'weierMultiplications': 5734,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3365,
#   'hadanoMultiplications': 6483,
#   'edwardsAdditions': 2618},
#  {'number': 704113633386627861528126049461637326014329259222520900313945499891961695911,
#   'endoMultiplications': 6289,
#   'endoAddition': 2486,
#   'weierAdditions': 2404,
#   'weierMultiplications': 5804,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3400,
#   'hadanoMultiplications': 6573,
#   'edwardsAdditions': 2653},
#  {'number': 958477028422752092601684627540576506950838339371701770576518464020882347397,
#   'endoMultiplications': 5893,
#   'endoAddition': 2326,
#   'weierAdditions': 2333,
#   'weierMultiplications': 5666,
#   'montAdditions': 2494,
#   'montMultiplications': 2744,
#   'hadanoAdditions': 3333,
#   'hadanoMultiplications': 6392,
#   'edwardsAdditions': 2583},
#  {'number': 129624518785734831835386025001846076605246522185618129797213364326262708361,
#   'endoMultiplications': 5962,
#   'endoAddition': 2354,
#   'weierAdditions': 2329,
#   'weierMultiplications': 5646,
#   'montAdditions': 2464,
#   'montMultiplications': 2711,
#   'hadanoAdditions': 3317,
#   'hadanoMultiplications': 6377,
#   'edwardsAdditions': 2576},
#  {'number': 383951555349432783290479064787655522823232408968995433225518581411188458734,
#   'endoMultiplications': 6042,
#   'endoAddition': 2380,
#   'weierAdditions': 2370,
#   'weierMultiplications': 5732,
#   'montAdditions': 2474,
#   'montMultiplications': 2722,
#   'hadanoAdditions': 3362,
#   'hadanoMultiplications': 6484,
#   'edwardsAdditions': 2618},
#  {'number': 381555949085473178042926284814941560867253941407017528183956285363031821136,
#   'endoMultiplications': 6078,
#   'endoAddition': 2390,
#   'weierAdditions': 2349,
#   'weierMultiplications': 5690,
#   'montAdditions': 2474,
#   'montMultiplications': 2722,
#   'hadanoAdditions': 3341,
#   'hadanoMultiplications': 6430,
#   'edwardsAdditions': 2597},
#  {'number': 812225343672434620277693368652088610269472853600111581454952976896397972849,
#   'endoMultiplications': 5929,
#   'endoAddition': 2331,
#   'weierAdditions': 2348,
#   'weierMultiplications': 5692,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3344,
#   'hadanoMultiplications': 6429,
#   'edwardsAdditions': 2597},
#  {'number': 934144424203591072734291120601722753285270310102410204118281272258681529547,
#   'endoMultiplications': 6217,
#   'endoAddition': 2462,
#   'weierAdditions': 2368,
#   'weierMultiplications': 5736,
#   'montAdditions': 2494,
#   'montMultiplications': 2744,
#   'hadanoAdditions': 3368,
#   'hadanoMultiplications': 6482,
#   'edwardsAdditions': 2618},
#  {'number': 578135244658766558256734193525328728507761045606350284776803745019680664519,
#   'endoMultiplications': 5988,
#   'endoAddition': 2365,
#   'weierAdditions': 2320,
#   'weierMultiplications': 5636,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3316,
#   'hadanoMultiplications': 6357,
#   'edwardsAdditions': 2569},
#  {'number': 853016995571404183743452838469596046547076447304886566234787572619562880427,
#   'endoMultiplications': 5965,
#   'endoAddition': 2353,
#   'weierAdditions': 2404,
#   'weierMultiplications': 5804,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3400,
#   'hadanoMultiplications': 6573,
#   'edwardsAdditions': 2653},
#  {'number': 777105297583495876218889387130496858041275935303223697893053538750256106746,
#   'endoMultiplications': 5983,
#   'endoAddition': 2369,
#   'weierAdditions': 2397,
#   'weierMultiplications': 5790,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3393,
#   'hadanoMultiplications': 6555,
#   'edwardsAdditions': 2646},
#  {'number': 628508543663455421970712837275565083678442669625192454237215613224884335467,
#   'endoMultiplications': 6073,
#   'endoAddition': 2396,
#   'weierAdditions': 2432,
#   'weierMultiplications': 5860,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3428,
#   'hadanoMultiplications': 6645,
#   'edwardsAdditions': 2681},
#  {'number': 676269171671984302515867613667454288190523088688953804714135257817750600054,
#   'endoMultiplications': 6307,
#   'endoAddition': 2494,
#   'weierAdditions': 2355,
#   'weierMultiplications': 5706,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3351,
#   'hadanoMultiplications': 6447,
#   'edwardsAdditions': 2604},
#  {'number': 113675655316907413926579175775305910706311115462904864635673489779045103544,
#   'endoMultiplications': 6183,
#   'endoAddition': 2453,
#   'weierAdditions': 2252,
#   'weierMultiplications': 5492,
#   'montAdditions': 2464,
#   'montMultiplications': 2711,
#   'hadanoAdditions': 3240,
#   'hadanoMultiplications': 6179,
#   'edwardsAdditions': 2499},
#  {'number': 398610963523388208189788367811910694833852416416738867835567831548267097475,
#   'endoMultiplications': 6024,
#   'endoAddition': 2376,
#   'weierAdditions': 2454,
#   'weierMultiplications': 5900,
#   'montAdditions': 2474,
#   'montMultiplications': 2722,
#   'hadanoAdditions': 3446,
#   'hadanoMultiplications': 6700,
#   'edwardsAdditions': 2702},
#  {'number': 558793348419828747375000513958072266124995330627397471646079514713908050669,
#   'endoMultiplications': 6096,
#   'endoAddition': 2401,
#   'weierAdditions': 2390,
#   'weierMultiplications': 5776,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3386,
#   'hadanoMultiplications': 6537,
#   'edwardsAdditions': 2639},
#  {'number': 188014044133045840282164463166489544560617879897101024196592771588871242179,
#   'endoMultiplications': 5998,
#   'endoAddition': 2360,
#   'weierAdditions': 2294,
#   'weierMultiplications': 5576,
#   'montAdditions': 2464,
#   'montMultiplications': 2711,
#   'hadanoAdditions': 3282,
#   'hadanoMultiplications': 6287,
#   'edwardsAdditions': 2541},
#  {'number': 175113527873506873698672971841100989942755732534918017695470374652140445440,
#   'endoMultiplications': 6160,
#   'endoAddition': 2437,
#   'weierAdditions': 2364,
#   'weierMultiplications': 5716,
#   'montAdditions': 2464,
#   'montMultiplications': 2711,
#   'hadanoAdditions': 3352,
#   'hadanoMultiplications': 6467,
#   'edwardsAdditions': 2611},
#  {'number': 643142845846603838448927148669178144958187486302319266180944373736872702236,
#   'endoMultiplications': 6019,
#   'endoAddition': 2379,
#   'weierAdditions': 2460,
#   'weierMultiplications': 5916,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3456,
#   'hadanoMultiplications': 6717,
#   'edwardsAdditions': 2709},
#  {'number': 613752294249546312749810728763372329150200212484871389830746822161471541107,
#   'endoMultiplications': 6168,
#   'endoAddition': 2444,
#   'weierAdditions': 2369,
#   'weierMultiplications': 5734,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3365,
#   'hadanoMultiplications': 6483,
#   'edwardsAdditions': 2618},
#  {'number': 634497999324616895646541711979344315196942948085225657974044281222034995710,
#   'endoMultiplications': 6091,
#   'endoAddition': 2404,
#   'weierAdditions': 2418,
#   'weierMultiplications': 5832,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3414,
#   'hadanoMultiplications': 6609,
#   'edwardsAdditions': 2667},
#  {'number': 507010745182255042769689088655694564234415700326355817537193492158442412847,
#   'endoMultiplications': 6024,
#   'endoAddition': 2370,
#   'weierAdditions': 2397,
#   'weierMultiplications': 5790,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3393,
#   'hadanoMultiplications': 6555,
#   'edwardsAdditions': 2646},
#  {'number': 450522859642462896824752434522957158124942197282344898651042648534680519396,
#   'endoMultiplications': 5862,
#   'endoAddition': 2300,
#   'weierAdditions': 2426,
#   'weierMultiplications': 5844,
#   'montAdditions': 2474,
#   'montMultiplications': 2722,
#   'hadanoAdditions': 3418,
#   'hadanoMultiplications': 6628,
#   'edwardsAdditions': 2674},
#  {'number': 270936913601110116127078619124244333388025055964737362627204155921692444387,
#   'endoMultiplications': 5903,
#   'endoAddition': 2326,
#   'weierAdditions': 2279,
#   'weierMultiplications': 5550,
#   'montAdditions': 2474,
#   'montMultiplications': 2722,
#   'hadanoAdditions': 3271,
#   'hadanoMultiplications': 6250,
#   'edwardsAdditions': 2527},
#  {'number': 896827375748202341998855694200838278078500999551757462339758319028903254683,
#   'endoMultiplications': 6001,
#   'endoAddition': 2360,
#   'weierAdditions': 2432,
#   'weierMultiplications': 5860,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3428,
#   'hadanoMultiplications': 6645,
#   'edwardsAdditions': 2681},
#  {'number': 618539441550921176575180763006070493972190094493191663057851857334576346903,
#   'endoMultiplications': 6037,
#   'endoAddition': 2379,
#   'weierAdditions': 2432,
#   'weierMultiplications': 5860,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3428,
#   'hadanoMultiplications': 6645,
#   'edwardsAdditions': 2681},
#  {'number': 238714082525633945779372532716409890423026883195560876355565869616547975226,
#   'endoMultiplications': 5813,
#   'endoAddition': 2289,
#   'weierAdditions': 2335,
#   'weierMultiplications': 5662,
#   'montAdditions': 2474,
#   'montMultiplications': 2722,
#   'hadanoAdditions': 3327,
#   'hadanoMultiplications': 6394,
#   'edwardsAdditions': 2583},
#  {'number': 731274240070320684382311857079483218269568235117534343183803442765874929733,
#   'endoMultiplications': 6037,
#   'endoAddition': 2380,
#   'weierAdditions': 2327,
#   'weierMultiplications': 5650,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3323,
#   'hadanoMultiplications': 6375,
#   'edwardsAdditions': 2576},
#  {'number': 626375381556508432667983191308542906141443423563294204225850815935057795637,
#   'endoMultiplications': 6109,
#   'endoAddition': 2412,
#   'weierAdditions': 2383,
#   'weierMultiplications': 5762,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3379,
#   'hadanoMultiplications': 6519,
#   'edwardsAdditions': 2632},
#  {'number': 716555159652693683934068889765071878088106998438484930792368587548145623505,
#   'endoMultiplications': 5893,
#   'endoAddition': 2328,
#   'weierAdditions': 2411,
#   'weierMultiplications': 5818,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3407,
#   'hadanoMultiplications': 6591,
#   'edwardsAdditions': 2660},
#  {'number': 540079220639915445025007014834747925408633832001275212759353695204061000233,
#   'endoMultiplications': 6024,
#   'endoAddition': 2383,
#   'weierAdditions': 2334,
#   'weierMultiplications': 5664,
#   'montAdditions': 2484,
#   'montMultiplications': 2733,
#   'hadanoAdditions': 3330,
#   'hadanoMultiplications': 6393,
#   'edwardsAdditions': 2583}]

# %%
len("6043422556832972882497885954803044486949960629401906949314")
# Out:
# 58
